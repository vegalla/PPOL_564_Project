# %% [markdown]
# # Merge All Data to Prepare for Analysis
#
# ## Purpose: Merge the following data in preparation for analysis
# * "Base" (Daily Google Mobility + COVID-19)
# * "VDE" (Locality Voter Preferences in 2020)
# * "NOAA" (Daily Precipitation)
# * "Census" (Locality 2019 Population Estimates)
#
# ## Dependencies

# %%
import pandas as pd
import missingno as msno
from plotnine import *

## For Multiple Outputs 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
## Google Mobility & COVID-19 (daily)
base = pd.read_csv("data/build/build1_base.csv")

base.head()
# Out:
#   Report Date   FIPS   Locality VDH Health District  Total Cases  \
# 0  2020-03-17  51001   Accomack       Eastern Shore            0
# 1  2020-03-17  51003  Albemarle    Thomas Jefferson            0
# 2  2020-03-17  51005  Alleghany           Alleghany            0
# 3  2020-03-17  51007     Amelia            Piedmont            0
# 4  2020-03-17  51009    Amherst    Central Virginia            0
#
#    Hospitalizations  Deaths country_region_code country_region sub_region_1  \
# 0                 0       0                  US  United States     Virginia
# 1                 0       0                  US  United States     Virginia
# 2                 0       0                  US  United States     Virginia
# 3                 0       0                  US  United States     Virginia
# 4                 0       0                  US  United States     Virginia
#
#    ... metro_area  iso_3166_2_code  census_fips_code        date  \
# 0  ...        NaN              NaN           51001.0  2020-03-17
# 1  ...        NaN              NaN           51003.0  2020-03-17
# 2  ...        NaN              NaN           51005.0  2020-03-17
# 3  ...        NaN              NaN           51007.0  2020-03-17
# 4  ...        NaN              NaN           51009.0  2020-03-17
#
#   retail_and_recreation_percent_change_from_baseline  \
# 0                                               -8.0
# 1                                              -22.0
# 2                                              -11.0
# 3                                              -21.0
# 4                                                3.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               11.0
# 1                                                9.0
# 2                                                NaN
# 3                                                6.0
# 4                                               22.0
#
#    parks_percent_change_from_baseline  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            NaN
# 1                                          -16.0
# 2                                            8.0
# 3                                            NaN
# 4                                            NaN
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -15.0
# 1                                    -38.0
# 2                                    -12.0
# 3                                    -18.0
# 4                                    -13.0
#
#    residential_percent_change_from_baseline
# 0                                       5.0
# 1                                      14.0
# 2                                       NaN
# 3                                       NaN
# 4                                       6.0
#
# [5 rows x 21 columns]

# %%
## VDE - Voter Preferences in 2020 Election (county)
vde = pd.read_csv("data/build/build2_locality.csv")

vde.head()
# Out:
#            Locality  P_Democrat  P_Republican  S_Democrat  S_Republican
# 0   ACCOMACK COUNTY           0             1           0             1
# 1  ALBEMARLE COUNTY           1             0           1             0
# 2   ALEXANDRIA CITY           1             0           1             0
# 3  ALLEGHANY COUNTY           0             1           0             1
# 4     AMELIA COUNTY           0             1           0             1

# %%
## NOAA - Precipitation (daily)
noaa = pd.read_csv("data/build/build3_precipitation.csv")

noaa.head()
# Out:
#           COUNTY   FIPS        DATE   PRCP
# 0  Amelia County  51007  2020-03-17  0.000
# 1  Amelia County  51007  2020-03-18  0.000
# 2  Amelia County  51007  2020-03-19  0.095
# 3  Amelia County  51007  2020-03-20  0.000
# 4  Amelia County  51007  2020-03-21  0.145

# %%
## Census - Estimated 2019 population & 2018 5-year estimates of income (county)
census = pd.read_csv('data/build/build4_census.csv')

census.head()
# Out:
#     FIPS     2019  DP03_0062E  DP03_0063E
# 0  51001   32,316       43210       57996
# 1  51003  109,330       75394      107948
# 2  51005   14,860       47794       60513
# 3  51007   13,145       58526       74185
# 4  51009   31,605       49170       61676

# %%
## Standardize VDE "LOCALITY"
vde['LOCALITY'] = vde['Locality'].str.replace(" COUNTY", "")
vde['LOCALITY'] = vde['LOCALITY'].str.replace('&', 'AND')

vde.head()
# Out:
#            Locality  P_Democrat  P_Republican  S_Democrat  S_Republican  \
# 0   ACCOMACK COUNTY           0             1           0             1
# 1  ALBEMARLE COUNTY           1             0           1             0
# 2   ALEXANDRIA CITY           1             0           1             0
# 3  ALLEGHANY COUNTY           0             1           0             1
# 4     AMELIA COUNTY           0             1           0             1
#
#           LOCALITY
# 0         ACCOMACK
# 1        ALBEMARLE
# 2  ALEXANDRIA CITY
# 3        ALLEGHANY
# 4           AMELIA

# %%
## Remove one locality variable
vde1 = vde[['LOCALITY','P_Democrat','P_Republican','S_Democrat','S_Republican']]

# %%
## Standardize Base "LOCALITY"

base["LOCALITY"] = base["Locality"].str.upper()

## [NOTE - CONSIDER CONVERTING THIS TO FUNCTION]
base.loc[base['LOCALITY'] == 'ALEXANDRIA', 'LOCALITY'] = 'ALEXANDRIA CITY'
base.loc[base['LOCALITY'] == 'BRISTOL', 'LOCALITY'] = 'BRISTOL CITY'
base.loc[base['LOCALITY'] == 'CHARLOTTESVILLE', 'LOCALITY'] = 'CHARLOTTESVILLE CITY'
base.loc[base['LOCALITY'] == 'CHESAPEAKE', 'LOCALITY'] = 'CHESAPEAKE CITY'
base.loc[base['LOCALITY'] == 'COLONIAL HEIGHTS', 'LOCALITY'] = 'COLONIAL HEIGHTS CITY'
base.loc[base['LOCALITY'] == 'COVINGTON', 'LOCALITY'] = 'COVINGTON CITY'
base.loc[base['LOCALITY'] == 'DANVILLE', 'LOCALITY'] = 'DANVILLE CITY'
base.loc[base['LOCALITY'] == 'EMPORIA', 'LOCALITY'] = 'EMPORIA CITY'
base.loc[base['LOCALITY'] == 'FAIRFAX', 'LOCALITY'] = 'FAIRFAX CITY'
base.loc[base['LOCALITY'] == 'FALLS CHURCH', 'LOCALITY'] = 'FALLS CHURCH CITY'
base.loc[base['LOCALITY'] == 'FRANKLIN', 'LOCALITY'] = 'FRANKLIN CITY'
base.loc[base['LOCALITY'] == 'FREDERICKSBURG', 'LOCALITY'] = 'FREDERICKSBURG CITY'
base.loc[base['LOCALITY'] == 'GALAX', 'LOCALITY'] = 'GALAX CITY'
base.loc[base['LOCALITY'] == 'HAMPTON', 'LOCALITY'] = 'HAMPTON CITY'
base.loc[base['LOCALITY'] == 'HARRISONBURG', 'LOCALITY'] = 'HARRISONBURG CITY'
base.loc[base['LOCALITY'] == 'HOPEWELL', 'LOCALITY'] = 'HOPEWELL CITY'
base.loc[base['LOCALITY'] == 'LEXINGTON', 'LOCALITY'] = 'LEXINGTON CITY'
base.loc[base['LOCALITY'] == 'LYNCHBURG', 'LOCALITY'] = 'LYNCHBURG CITY'
base.loc[base['LOCALITY'] == 'MANASSAS PARK', 'LOCALITY'] = 'MANASSAS PARK CITY'
base.loc[base['LOCALITY'] == 'MARTINSVILLE', 'LOCALITY'] = 'MARTINSVILLE CITY'
base.loc[base['LOCALITY'] == 'NEWPORT NEWS', 'LOCALITY'] = 'NEWPORT NEWS CITY'
base.loc[base['LOCALITY'] == 'NORFOLK', 'LOCALITY'] = 'NORFOLK CITY'
base.loc[base['LOCALITY'] == 'NORTON', 'LOCALITY'] = 'NORTON CITY'
base.loc[base['LOCALITY'] == 'PETERSBURG', 'LOCALITY'] = 'PETERSBURG CITY'
base.loc[base['LOCALITY'] == 'POQUOSON', 'LOCALITY'] = 'POQUOSON CITY'
base.loc[base['LOCALITY'] == 'PORTSMOUTH', 'LOCALITY'] = 'PORTSMOUTH CITY'
base.loc[base['LOCALITY'] == 'RADFORD', 'LOCALITY'] = 'RADFORD CITY'
base.loc[base['LOCALITY'] == 'RICHMOND', 'LOCALITY'] = 'RICHMOND CITY'
base.loc[base['LOCALITY'] == 'ROANOKE', 'LOCALITY'] = 'ROANOKE CITY'
base.loc[base['LOCALITY'] == 'SALEM', 'LOCALITY'] = 'SALEM CITY'
base.loc[base['LOCALITY'] == 'STAUNTON', 'LOCALITY'] = 'STAUNTON CITY'
base.loc[base['LOCALITY'] == 'SUFFOLK', 'LOCALITY'] = 'SUFFOLK CITY'
base.loc[base['LOCALITY'] == 'VIRGINIA BEACH', 'LOCALITY'] = 'VIRGINIA BEACH CITY'
base.loc[base['LOCALITY'] == 'WAYNESBORO', 'LOCALITY'] = 'WAYNESBORO CITY'
base.loc[base['LOCALITY'] == 'WILLIAMSBURG', 'LOCALITY'] = 'WILLIAMSBURG CITY'
base.loc[base['LOCALITY'] == 'WINCHESTER', 'LOCALITY'] = 'WINCHESTER CITY'

base.head()
# Out:
#   Report Date   FIPS   Locality VDH Health District  Total Cases  \
# 0  2020-03-17  51001   Accomack       Eastern Shore            0
# 1  2020-03-17  51003  Albemarle    Thomas Jefferson            0
# 2  2020-03-17  51005  Alleghany           Alleghany            0
# 3  2020-03-17  51007     Amelia            Piedmont            0
# 4  2020-03-17  51009    Amherst    Central Virginia            0
#
#    Hospitalizations  Deaths country_region_code country_region sub_region_1  \
# 0                 0       0                  US  United States     Virginia
# 1                 0       0                  US  United States     Virginia
# 2                 0       0                  US  United States     Virginia
# 3                 0       0                  US  United States     Virginia
# 4                 0       0                  US  United States     Virginia
#
#    ... iso_3166_2_code  census_fips_code        date  \
# 0  ...             NaN           51001.0  2020-03-17
# 1  ...             NaN           51003.0  2020-03-17
# 2  ...             NaN           51005.0  2020-03-17
# 3  ...             NaN           51007.0  2020-03-17
# 4  ...             NaN           51009.0  2020-03-17
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                               -8.0
# 1                                              -22.0
# 2                                              -11.0
# 3                                              -21.0
# 4                                                3.0
#
#   grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                              11.0
# 1                                               9.0
# 2                                               NaN
# 3                                               6.0
# 4                                              22.0
#
#    parks_percent_change_from_baseline  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            NaN
# 1                                          -16.0
# 2                                            8.0
# 3                                            NaN
# 4                                            NaN
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -15.0
# 1                                    -38.0
# 2                                    -12.0
# 3                                    -18.0
# 4                                    -13.0
#
#    residential_percent_change_from_baseline   LOCALITY
# 0                                       5.0   ACCOMACK
# 1                                      14.0  ALBEMARLE
# 2                                       NaN  ALLEGHANY
# 3                                       NaN     AMELIA
# 4                                       6.0    AMHERST
#
# [5 rows x 22 columns]

# %%
## Pre-Merge dimensions
base.shape

## Inner Merge
base1 = base.merge(vde1, how= "inner", on= "LOCALITY")

## Post-merge dimensions (Should be identical row count)
base1.shape

base1.head()
# Out:
# (33649, 22)
# (33649, 26)
#   Report Date   FIPS  Locality VDH Health District  Total Cases  \
# 0  2020-03-17  51001  Accomack       Eastern Shore            0
# 1  2020-03-18  51001  Accomack       Eastern Shore            0
# 2  2020-03-19  51001  Accomack       Eastern Shore            0
# 3  2020-03-20  51001  Accomack       Eastern Shore            1
# 4  2020-03-21  51001  Accomack       Eastern Shore            1
#
#    Hospitalizations  Deaths country_region_code country_region sub_region_1  \
# 0                 0       0                  US  United States     Virginia
# 1                 0       0                  US  United States     Virginia
# 2                 0       0                  US  United States     Virginia
# 3                 0       0                  US  United States     Virginia
# 4                 0       0                  US  United States     Virginia
#
#    ... grocery_and_pharmacy_percent_change_from_baseline  \
# 0  ...                                              11.0
# 1  ...                                               9.0
# 2  ...                                               8.0
# 3  ...                                               3.0
# 4  ...                                               9.0
#
#    parks_percent_change_from_baseline  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -15.0
# 1                                    -17.0
# 2                                    -18.0
# 3                                    -17.0
# 4                                      4.0
#
#   residential_percent_change_from_baseline  LOCALITY  P_Democrat  \
# 0                                      5.0  ACCOMACK           0
# 1                                      8.0  ACCOMACK           0
# 2                                      8.0  ACCOMACK           0
# 3                                     10.0  ACCOMACK           0
# 4                                      NaN  ACCOMACK           0
#
#    P_Republican  S_Democrat  S_Republican
# 0             1           0             1
# 1             1           0             1
# 2             1           0             1
# 3             1           0             1
# 4             1           0             1
#
# [5 rows x 26 columns]

# %%
## Standardize date
base1['DATE'] = pd.to_datetime(base1['Report Date'])

min(base1['DATE'])
max(base1['DATE'])
# Out:
# Timestamp('2020-03-17 00:00:00')
# Timestamp('2020-11-24 00:00:00')

# %%
## Standardize date
noaa['DATE'] = pd.to_datetime(noaa['DATE'])

min(noaa['DATE'])
max(noaa['DATE'])
# Out:
# Timestamp('2020-03-17 00:00:00')
# Timestamp('2020-11-23 00:00:00')

# %%
## Pre-Merge dimensions
base1.shape

## Inner Merge
base2 = base1.merge(noaa, how= "left", on= ['DATE','FIPS'])

## Post-merge dimensions (Should be identical row count)
base2.shape

base2.head()
# Out:
# (33649, 27)
# (33649, 29)
#   Report Date   FIPS  Locality VDH Health District  Total Cases  \
# 0  2020-03-17  51001  Accomack       Eastern Shore            0
# 1  2020-03-18  51001  Accomack       Eastern Shore            0
# 2  2020-03-19  51001  Accomack       Eastern Shore            0
# 3  2020-03-20  51001  Accomack       Eastern Shore            1
# 4  2020-03-21  51001  Accomack       Eastern Shore            1
#
#    Hospitalizations  Deaths country_region_code country_region sub_region_1  \
# 0                 0       0                  US  United States     Virginia
# 1                 0       0                  US  United States     Virginia
# 2                 0       0                  US  United States     Virginia
# 3                 0       0                  US  United States     Virginia
# 4                 0       0                  US  United States     Virginia
#
#    ... workplaces_percent_change_from_baseline  \
# 0  ...                                   -15.0
# 1  ...                                   -17.0
# 2  ...                                   -18.0
# 3  ...                                   -17.0
# 4  ...                                     4.0
#
#    residential_percent_change_from_baseline  LOCALITY  P_Democrat  \
# 0                                       5.0  ACCOMACK           0
# 1                                       8.0  ACCOMACK           0
# 2                                       8.0  ACCOMACK           0
# 3                                      10.0  ACCOMACK           0
# 4                                       NaN  ACCOMACK           0
#
#   P_Republican  S_Democrat  S_Republican       DATE  COUNTY  PRCP
# 0            1           0             1 2020-03-17     NaN   NaN
# 1            1           0             1 2020-03-18     NaN   NaN
# 2            1           0             1 2020-03-19     NaN   NaN
# 3            1           0             1 2020-03-20     NaN   NaN
# 4            1           0             1 2020-03-21     NaN   NaN
#
# [5 rows x 29 columns]

# %%
## Visualize missing data - Only 50/133 counties had daily precipitation data from NOAA
msno.matrix(base2)
# Out:
# <AxesSubplot:>

# %%
## Pre-Merge dimensions
base2.shape

## Inner Merge
base3 = base2.merge(census, how= "inner", on= 'FIPS')

## Post-merge dimensions (Should be identical row count)
base3.shape

base3.head()
# Out:
# (33649, 29)
# (33649, 32)
#   Report Date   FIPS  Locality VDH Health District  Total Cases  \
# 0  2020-03-17  51001  Accomack       Eastern Shore            0
# 1  2020-03-18  51001  Accomack       Eastern Shore            0
# 2  2020-03-19  51001  Accomack       Eastern Shore            0
# 3  2020-03-20  51001  Accomack       Eastern Shore            1
# 4  2020-03-21  51001  Accomack       Eastern Shore            1
#
#    Hospitalizations  Deaths country_region_code country_region sub_region_1  \
# 0                 0       0                  US  United States     Virginia
# 1                 0       0                  US  United States     Virginia
# 2                 0       0                  US  United States     Virginia
# 3                 0       0                  US  United States     Virginia
# 4                 0       0                  US  United States     Virginia
#
#    ... P_Democrat  P_Republican  S_Democrat  S_Republican       DATE  COUNTY  \
# 0  ...          0             1           0             1 2020-03-17     NaN
# 1  ...          0             1           0             1 2020-03-18     NaN
# 2  ...          0             1           0             1 2020-03-19     NaN
# 3  ...          0             1           0             1 2020-03-20     NaN
# 4  ...          0             1           0             1 2020-03-21     NaN
#
#    PRCP    2019  DP03_0062E  DP03_0063E
# 0   NaN  32,316       43210       57996
# 1   NaN  32,316       43210       57996
# 2   NaN  32,316       43210       57996
# 3   NaN  32,316       43210       57996
# 4   NaN  32,316       43210       57996
#
# [5 rows x 32 columns]

# %%
base3 = base3.sort_values(by= ['FIPS','DATE'])

# %%
## Lag Total Cases per day per locality
base3['lag_case'] = base3.groupby('FIPS')['Total Cases'].shift(1)

## Calculate daily delta of cases
base3['delta_case00'] = base3['Total Cases'] - base3['lag_case']
base3['delta_case01'] = base3.groupby('FIPS')['delta_case00'].shift(1)
base3['delta_case02'] = base3.groupby('FIPS')['delta_case01'].shift(1)
base3['delta_case03'] = base3.groupby('FIPS')['delta_case02'].shift(1)
base3['delta_case04'] = base3.groupby('FIPS')['delta_case03'].shift(1)
base3['delta_case05'] = base3.groupby('FIPS')['delta_case04'].shift(1)
base3['delta_case06'] = base3.groupby('FIPS')['delta_case05'].shift(1)
base3['delta_case07'] = base3.groupby('FIPS')['delta_case06'].shift(1)
base3['delta_case08'] = base3.groupby('FIPS')['delta_case07'].shift(1)
base3['delta_case09'] = base3.groupby('FIPS')['delta_case08'].shift(1)
base3['delta_case10'] = base3.groupby('FIPS')['delta_case09'].shift(1)
base3['delta_case11'] = base3.groupby('FIPS')['delta_case10'].shift(1)
base3['delta_case12'] = base3.groupby('FIPS')['delta_case11'].shift(1)
base3['delta_case13'] = base3.groupby('FIPS')['delta_case12'].shift(1)

## Sum delta0-6 for weekly delta
base3['weekly_delta_cases'] = (base3['delta_case00'] +
                                  base3['delta_case01'] + 
                                  base3['delta_case02'] +
                                  base3['delta_case03'] + 
                                  base3['delta_case04'] +
                                  base3['delta_case05'] + 
                                  base3['delta_case06'])

## Sum delta0-13 for biweekly delta
base3['biweekly_delta_cases'] = (base3['delta_case00'] +
                                  base3['delta_case01'] + 
                                  base3['delta_case02'] +
                                  base3['delta_case03'] + 
                                  base3['delta_case04'] +
                                  base3['delta_case05'] + 
                                  base3['delta_case06'] +
                                  base3['delta_case07'] + 
                                  base3['delta_case08'] +
                                  base3['delta_case09'] + 
                                  base3['delta_case10'] +
                                  base3['delta_case11'] + 
                                  base3['delta_case12'] + 
                                  base3['delta_case13'])

## Check some values
base3
# Out:
#       Report Date   FIPS    Locality VDH Health District  Total Cases  \
# 0      2020-03-17  51001    Accomack       Eastern Shore            0
# 1      2020-03-18  51001    Accomack       Eastern Shore            0
# 2      2020-03-19  51001    Accomack       Eastern Shore            0
# 3      2020-03-20  51001    Accomack       Eastern Shore            1
# 4      2020-03-21  51001    Accomack       Eastern Shore            1
# ...           ...    ...         ...                 ...          ...
# 33644  2020-11-20  51840  Winchester        Lord Fairfax          847
# 33645  2020-11-21  51840  Winchester        Lord Fairfax          855
# 33646  2020-11-22  51840  Winchester        Lord Fairfax          863
# 33647  2020-11-23  51840  Winchester        Lord Fairfax          890
# 33648  2020-11-24  51840  Winchester        Lord Fairfax          904
#
#        Hospitalizations  Deaths country_region_code country_region  \
# 0                     0       0                  US  United States
# 1                     0       0                  US  United States
# 2                     0       0                  US  United States
# 3                     0       0                  US  United States
# 4                     0       0                  US  United States
# ...                 ...     ...                 ...            ...
# 33644                50       4                  US  United States
# 33645                51       4                  US  United States
# 33646                51       4                  US  United States
# 33647                52       4                  US  United States
# 33648                55       4                  US  United States
#
#       sub_region_1  ... delta_case06  delta_case07  delta_case08  \
# 0         Virginia  ...          NaN           NaN           NaN
# 1         Virginia  ...          NaN           NaN           NaN
# 2         Virginia  ...          NaN           NaN           NaN
# 3         Virginia  ...          NaN           NaN           NaN
# 4         Virginia  ...          NaN           NaN           NaN
# ...            ...  ...          ...           ...           ...
# 33644     Virginia  ...         19.0          15.0          10.0
# 33645     Virginia  ...          5.0          19.0          15.0
# 33646     Virginia  ...          3.0           5.0          19.0
# 33647     Virginia  ...         17.0           3.0           5.0
# 33648     Virginia  ...         29.0          17.0           3.0
#
#        delta_case09 delta_case10  delta_case11  delta_case12  delta_case13  \
# 0               NaN          NaN           NaN           NaN           NaN
# 1               NaN          NaN           NaN           NaN           NaN
# 2               NaN          NaN           NaN           NaN           NaN
# 3               NaN          NaN           NaN           NaN           NaN
# 4               NaN          NaN           NaN           NaN           NaN
# ...             ...          ...           ...           ...           ...
# 33644           7.0          9.0          13.0           6.0           5.0
# 33645          10.0          7.0           9.0          13.0           6.0
# 33646          15.0         10.0           7.0           9.0          13.0
# 33647          19.0         15.0          10.0           7.0           9.0
# 33648           5.0         19.0          15.0          10.0           7.0
#
#        weekly_delta_cases  biweekly_delta_cases
# 0                     NaN                   NaN
# 1                     NaN                   NaN
# 2                     NaN                   NaN
# 3                     NaN                   NaN
# 4                     NaN                   NaN
# ...                   ...                   ...
# 33644               102.0                 167.0
# 33645                91.0                 170.0
# 33646                94.0                 172.0
# 33647               118.0                 186.0
# 33648               115.0                 191.0
#
# [33649 rows x 49 columns]

# %%
## Lag Total Deaths per day per locality
base3['lag_death'] = base3.groupby('FIPS')['Deaths'].shift(1)

## Calculate daily delta of deaths
base3['delta_death00'] = base3['Deaths'] - base3['lag_death']
base3['delta_death01'] = base3.groupby('FIPS')['delta_death00'].shift(1)
base3['delta_death02'] = base3.groupby('FIPS')['delta_death01'].shift(1)
base3['delta_death03'] = base3.groupby('FIPS')['delta_death02'].shift(1)
base3['delta_death04'] = base3.groupby('FIPS')['delta_death03'].shift(1)
base3['delta_death05'] = base3.groupby('FIPS')['delta_death04'].shift(1)
base3['delta_death06'] = base3.groupby('FIPS')['delta_death05'].shift(1)

## Sum delta0-6 for weekly delta
base3['weekly_delta_deaths'] = (base3['delta_death00'] +
                                  base3['delta_death01'] + 
                                  base3['delta_death02'] +
                                  base3['delta_death03'] + 
                                  base3['delta_death04'] +
                                  base3['delta_death05'] + 
                                  base3['delta_death06'])
## Check some values
base3
# Out:
#       Report Date   FIPS    Locality VDH Health District  Total Cases  \
# 0      2020-03-17  51001    Accomack       Eastern Shore            0
# 1      2020-03-18  51001    Accomack       Eastern Shore            0
# 2      2020-03-19  51001    Accomack       Eastern Shore            0
# 3      2020-03-20  51001    Accomack       Eastern Shore            1
# 4      2020-03-21  51001    Accomack       Eastern Shore            1
# ...           ...    ...         ...                 ...          ...
# 33644  2020-11-20  51840  Winchester        Lord Fairfax          847
# 33645  2020-11-21  51840  Winchester        Lord Fairfax          855
# 33646  2020-11-22  51840  Winchester        Lord Fairfax          863
# 33647  2020-11-23  51840  Winchester        Lord Fairfax          890
# 33648  2020-11-24  51840  Winchester        Lord Fairfax          904
#
#        Hospitalizations  Deaths country_region_code country_region  \
# 0                     0       0                  US  United States
# 1                     0       0                  US  United States
# 2                     0       0                  US  United States
# 3                     0       0                  US  United States
# 4                     0       0                  US  United States
# ...                 ...     ...                 ...            ...
# 33644                50       4                  US  United States
# 33645                51       4                  US  United States
# 33646                51       4                  US  United States
# 33647                52       4                  US  United States
# 33648                55       4                  US  United States
#
#       sub_region_1  ... biweekly_delta_cases  lag_death  delta_death00  \
# 0         Virginia  ...                  NaN        NaN            NaN
# 1         Virginia  ...                  NaN        0.0            0.0
# 2         Virginia  ...                  NaN        0.0            0.0
# 3         Virginia  ...                  NaN        0.0            0.0
# 4         Virginia  ...                  NaN        0.0            0.0
# ...            ...  ...                  ...        ...            ...
# 33644     Virginia  ...                167.0        4.0            0.0
# 33645     Virginia  ...                170.0        4.0            0.0
# 33646     Virginia  ...                172.0        4.0            0.0
# 33647     Virginia  ...                186.0        4.0            0.0
# 33648     Virginia  ...                191.0        4.0            0.0
#
#        delta_death01 delta_death02  delta_death03  delta_death04  \
# 0                NaN           NaN            NaN            NaN
# 1                NaN           NaN            NaN            NaN
# 2                0.0           NaN            NaN            NaN
# 3                0.0           0.0            NaN            NaN
# 4                0.0           0.0            0.0            NaN
# ...              ...           ...            ...            ...
# 33644            0.0           0.0            0.0            0.0
# 33645            0.0           0.0            0.0            0.0
# 33646            0.0           0.0            0.0            0.0
# 33647            0.0           0.0            0.0            0.0
# 33648            0.0           0.0            0.0            0.0
#
#        delta_death05  delta_death06  weekly_delta_deaths
# 0                NaN            NaN                  NaN
# 1                NaN            NaN                  NaN
# 2                NaN            NaN                  NaN
# 3                NaN            NaN                  NaN
# 4                NaN            NaN                  NaN
# ...              ...            ...                  ...
# 33644            0.0            0.0                  0.0
# 33645            0.0            0.0                  0.0
# 33646            0.0            0.0                  0.0
# 33647            0.0            0.0                  0.0
# 33648            0.0            0.0                  0.0
#
# [33649 rows x 58 columns]

# %%
## Flags for Phase 1-3
# source: https://www.cbs19news.com/story/42987299/total-number-of-covid19-cases-reaches-240063-in-virginia

## General Virginia Phases
base3['phase_1'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,5,13) <= x < pd.Timestamp(2020,6,5), 1, 0)
base3['phase_2'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,6,5) <= x < pd.Timestamp(2020,7,1), 1, 0)
base3['phase_3'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,7,1) <= x, 1, 0)

# %%
## Richmond Phases
base3.loc[(base3.FIPS == 51159) | (base3.FIPS == 51760),'phase_1'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,5,13) <= x < pd.Timestamp(2020,6,12), 1, 0)
base3.loc[(base3.FIPS == 51159) | (base3.FIPS == 51760),'phase_2'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,6,12) <= x < pd.Timestamp(2020,7,11), 1, 0)
base3.loc[(base3.FIPS == 51159) | (base3.FIPS == 51760),'phase_3'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,7,1) <= x, 1, 0)

# %%
## Nothern Virginia Phases
base3.loc[(base3.FIPS == 51013) | (base3.FIPS == 51059) | (base3.FIPS == 51107) | (base3.FIPS == 51153) | \
          (base3.FIPS == 51510) | (base3.FIPS == 51600) | (base3.FIPS == 51610) | (base3.FIPS == 51683) | \
          (base3.FIPS == 51685),'phase_1'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,5,29) <= x < pd.Timestamp(2020,6,12), 1, 0)
base3.loc[(base3.FIPS == 51013) | (base3.FIPS == 51059) | (base3.FIPS == 51107) | (base3.FIPS == 51153) | \
          (base3.FIPS == 51510) | (base3.FIPS == 51600) | (base3.FIPS == 51610) | (base3.FIPS == 51683) | \
          (base3.FIPS == 51685),'phase_1'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,6,12) <= x < pd.Timestamp(2020,7,1), 1, 0)
base3.loc[(base3.FIPS == 51013) | (base3.FIPS == 51059) | (base3.FIPS == 51107) | (base3.FIPS == 51153) | \
          (base3.FIPS == 51510) | (base3.FIPS == 51600) | (base3.FIPS == 51610) | (base3.FIPS == 51683) | \
          (base3.FIPS == 51685),'phase_1'] = base3['DATE'].apply(lambda x: pd.Timestamp(2020,7,1) <= x, 1, 0)

# %%
## Convert Population to Numeric

base3['Pop_2019'] = pd.to_numeric(base3['2019'].str.replace(",",""))

base3['Pop_2019'].dtype
# Out:
# dtype('int64')

# %%
## Lag Community Mobility for Model 4
base3['lag_cm'] = base3.groupby('FIPS')['retail_and_recreation_percent_change_from_baseline'].shift(1)

base3['delta_cm'] = base3['retail_and_recreation_percent_change_from_baseline'] - base3['lag_cm']

base3.loc[:,['retail_and_recreation_percent_change_from_baseline','lag_cm','delta_cm']]
# Out:
#        retail_and_recreation_percent_change_from_baseline  lag_cm  delta_cm
# 0                                                   -8.0      NaN       NaN
# 1                                                  -15.0     -8.0      -7.0
# 2                                                  -16.0    -15.0      -1.0
# 3                                                  -17.0    -16.0      -1.0
# 4                                                  -24.0    -17.0      -7.0
# ...                                                  ...      ...       ...
# 33644                                              -20.0    -14.0      -6.0
# 33645                                              -17.0    -20.0       3.0
# 33646                                              -15.0    -17.0       2.0
# 33647                                               -8.0    -15.0       7.0
# 33648                                               -4.0     -8.0       4.0
#
# [33649 rows x 3 columns]

# %%
Viz_cm= (
    ggplot(base3,
          aes(x="DATE",y="retail_and_recreation_percent_change_from_baseline", fill= 'Locality')) +
    geom_point(alpha=.15, show_legend = False) +
    labs(x = "Date",y= "Recreation Trend", title = "Google Recreation Trend from March 17 to November 24, 2020") +
    theme_bw() +
    theme(figure_size=(15,8)) +
    scale_x_date(date_labels = "%B") + 
    geom_vline(xintercept= "2020-07-01", linetype= "dashed", color= "darkred") + 
    annotate("text", x= "2020-07-10", y= 50, color= "darkred", label= "Phase 3")

)

Viz_cm
# Out:
# c:\users\vince\appdata\local\programs\python\python38\lib\site-packages\plotnine\layer.py:467: PlotnineWarning: geom_point : Removed 15430 rows containing missing values.
# <ggplot: (141284605477)>

# %%
base3.to_csv('data/build/build5_analysis_data.csv', index= False)
